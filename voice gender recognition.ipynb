# %%
import pandas as pd

# %%
data=pd.read_csv(r'F:\mukulml\KAGGLE\voice.csv\voice.csv')

# %%
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
data.shape
# Out:
# (3168, 21)

# %%
#checking correlation between features
data.corr()
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %%
#checkng is there any null value
data.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
data['label'].value_counts()
# Out:
# female    1584
# male      1584
# Name: label, dtype: int64

# %%
#seperating features and labels
x=data.iloc[:,:-1]
y=data.pop('label')

# %%
x.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  0.000000  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  0.000000  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  0.083878  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  0.104261  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx
# ...

# %%
#encoding the labels to 1--> male and female-->0
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
#scale the data between -1 and 1
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
#splitting the dataset into train test
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=30)

# %%
#running svm with default hyperparameter
from sklearn.svm import SVC
svc=SVC()
svc.fit(xtrain,ytrain)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
support_vectors=svc.support_vectors_
pd.DataFrame(support_vectors,columns=data.columns).head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0 -0.229153  0.088936 -0.435161  0.110875 -0.657071 -0.489213 -0.155680
# 1 -1.391002  0.667914 -1.019363 -0.299513 -2.396032 -0.983105  0.004842
# 2  0.373876 -0.420632  0.256123  0.539271 -0.439086 -0.856209 -0.367483
# 3  1.048532 -1.162536  0.825736  1.364084  0.126244 -1.482337  0.135137
# 4  0.193626 -0.698101 -0.233665  0.276148 -0.383374 -0.526038 -0.322133
#
#        kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0 -0.197093  0.678570  0.674587  0.077203 -0.229153 -0.032636 -1.406398
# 1 -0.165906  0.378428  0.734875 -0.150332 -1.391002 -0.020875 -1.044153
# 2 -0.235125  0.164504 -0.039021  0.552140  0.373876 -0.060596  0.618191
# 3 -0.130995 -1.628643 -1.148488  0.650234  1.048532  2.355515  8.492423
# 4 -0.219466 -0.219664 -0.919016 -0.099133  0.193626  0.159203  0.615625
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx
# ...

# %%
svc.n_support_ #no. of support vectors
# Out:
# array([157, 161])

# %%
svc.support_ #indices of support vectors
# Out:
# array([  36,   40,   66,   70,   87,   94,  101,  183,  195,  215,  218,
#         220,  232,  234,  240,  253,  265,  274,  276,  285,  296,  302,
#         306,  307,  319,  341,  348,  402,  430,  441,  468,  487,  501,
#         506,  507,  511,  519,  534,  539,  541,  556,  561,  584,  602,
#         609,  619,  629,  646,  671,  680,  682,  683,  692,  695,  702,
#         714,  719,  738,  769,  780,  809,  815,  819,  856,  875,  892,
#         895,  912,  921,  924,  929,  939,  947,  975, 1022, 1027, 1030,
#        1033, 1038, 1049, 1059, 1065, 1073, 1079, 1117, 1123, 1136, 1158,
#        1159, 1168, 1221, 1255, 1258, 1280, 1284, 1288, 1292, 1304, 1326,
#        1346, 1362, 1372, 1393, 1422, 1428, 1460, 1462, 1470, 1477, 1503,
#        1508, 1510, 1526, 1538, 1553, 1578, 1603, 1646, 1691, 1693, 1702,
#        1721, 1738, 1765, 1778, 1803, 1824, 1829, 1845, 1852, 1855, 1860,
#        1869, 1884, 1899, 1910, 1924, 1930, 1933, 1937, 1940, 1972, 2004,
# ...

# %%
from sklearn import metrics
ypred=svc.predict(xtest)
metrics.accuracy_score(ytest,ypred)
# Out:
# 0.9789695057833859

# %%
# %matplotlib inline
cmat=metrics.confusion_matrix(ytest,ypred)
import seaborn as sn

sn.heatmap(cmat,annot=True)

# %%
svc
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
#svm with linear kernel
svc=SVC(kernel='linear')
svc.fit(xtrain,ytrain)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
ypred=svc.predict(xtest)
metrics.accuracy_score(ytest,ypred)
# Out:
# 0.9758149316508938

# %%
cmat=metrics.confusion_matrix(ytest,ypred)
sn.heatmap(cmat,annot=True)

# %%
#polynomial kernel
sv=SVC(kernel='polynomial')
svc.fit(xtrain,ytrain)
ypred=svc.predict(xtest)
metrics.accuracy_score(ytest,ypred)
# Out:
# 0.9758149316508938

# %%
#k fold cross validation
from sklearn.model_selection import cross_val_score

# %%
svc=SVC(kernel='linear')
scores=cross_val_score(svc,x,y,cv=10,scoring='accuracy')
print(scores)
# Out:
# [0.91194969 0.97169811 0.97169811 0.97169811 0.96202532 0.98734177
#  0.99050633 0.98101266 0.95253165 0.99367089]

# %%
scores.mean()
# Out:
# 0.9694132632752168

# %%
svc=SVC(kernel='rbf')
scores=cross_val_score(svc,x,y,cv=10,scoring='accuracy')
print(scores)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
scores.mean()
# Out:
# 0.9659382214791815

# %%
import os
os.chdir(r'F:\mukulml\KAGGLE\voice.csv')
import pickle
filename='svc.pkl'
with open(filename,'wb') as file:
    pickle.dump(svc,file)

# %%
xtrain
# Out:
# array([[ 0.89601859, -0.90815535,  0.5762149 , ..., -1.27830503,
#         -1.26597189, -0.14509683],
#        [-0.42649736,  0.1713386 , -0.45738991, ..., -0.38179612,
#         -0.39359602,  0.40086943],
#        [ 0.95025006, -1.18704267,  0.61260495, ...,  0.70333471,
#          0.71185738, -0.54710492],
#        ...,
#        [-0.3824643 ,  0.22101472, -0.51135618, ..., -1.03836684,
#         -1.02512511,  2.60242989],
#        [ 0.61424817,  0.14921564,  1.016412  , ...,  0.17519332,
#          0.15469111,  0.4512314 ],
#        [-0.11820464, -1.1107444 , -0.36620001, ...,  0.49696013,
#          0.46546114, -0.18259259]])

# %%
with open(filename,'rb') as file:
    model=pickle.load(file)

# %%
#testing
data=pd.read_csv('voice.csv')
xtest=data.iloc[1:2,:-1].values

# %%
model.predict(xtest)
# Out:
# array([1])

# %%
model.score(xtrain,ytrain)
# Out:
# 0.9855660802886784
